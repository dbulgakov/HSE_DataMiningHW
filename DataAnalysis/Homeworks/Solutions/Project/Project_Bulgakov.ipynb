# %% [markdown]
# # 1. Loading Data

# %% [markdown]
# VK library quiet installation and import into the notebook.

# %%
# !pip install vk # makes it quiet
import vk

# %% [markdown]
# Starting new vk session in order to parse data

# %%
vk_session = vk.Session() # starting new session
vk_api = vk.API(vk_session)

# %% [markdown]
# Getting number of posts in selected vk group.

# %%
selected_group = 'overhearhse' # no other ideas :c
posts_number = vk_api.wall.get(domain=selected_group)[0] # number of posts is stored in first element
print('Number of posts in selected group: ', posts_number - 1)
# Out:
# Number of posts in selected group:  13124

# %% [markdown]
# Writing a function to parse more, than 100 posts from group.

# %%
def load_all_posts(page, n_posts, api):
    all_posts = api.wall.get(domain=page, count=n_posts)
    n_loaded = len(all_posts)
    while n_loaded < n_posts: # loop to load more, than 100 posts
        s = api.wall.get(domain=page, offset=n_loaded, count=(n_posts - n_loaded)) # update offset
        all_posts += s[1:] # no need for first element
        n_loaded += len(s) - 1 # update n_loaded
    return all_posts

# %% [markdown]
# Loading all posts from group for future analysis

# %%
try:
    loaded_posts = load_all_posts(page=selected_group, n_posts=posts_number, api=vk_api)[1:] # no need for posts number element
    print('Number of loaded posts: ', len(loaded_posts))
except: # timout errors are often to occur
    print('Error occured! Try again.')
# Out:
# Number of loaded posts:  13124

# %% [markdown]
# # 2. Data preprocessing

# %% [markdown]
# Loading required libs to preprocess data.

# %%
# !pip install pymorphy2 -q # silent install again
import pymorphy2 # need this one to convert words to normal time
import datetime # needed to convert response date 
import string # needed to work with strings
from nltk.tokenize import TweetTokenizer # needed to split text
import pandas as pd # required to work with dataframes
from ipywidgets import IntProgress # progressbar
from IPython.display import display # progressbar

# %% [markdown]
# Writing functions to process text data. Converting words to normal form and removing punctuation here.

# %%
def split_text(text):
    tokenizer = TweetTokenizer()
    return tokenizer.tokenize(text) # spliting text into words

def convert_to_normal_form(words_list):
    morph = pymorphy2.MorphAnalyzer()
    normal_forms_list = []
    for word in words_list:
        if word not in string.punctuation and word[0] != "<":
            norm_form = morph.parse(word)[0].normal_form #getting normal form of a word
            normal_forms_list.append(norm_form) #adding it to list
    return normal_forms_list

def convert_text(text):
    words_list = split_text(text) # spliting text into words
    norm_words_list = convert_to_normal_form(words_list) # words into normal form
    return norm_words_list

# %% [markdown]
# Writing a function to convert received list into another with another data.

# %%
def convert_posts(posts_list):
    progress = IntProgress() 
    progress.max = len(posts_list) # initializing progressbar
    progress.description = 'Processing data convertion'
    display(progress)
    
    updated_posts = [] # list of new posts' list structure
    for i, post in enumerate(posts_list): 
        tmp_dict = {} # creating empty dictionary for each post
        tmp_dict['likes_number'] = post['likes']['count'] # getting likes count
        tmp_dict['text'] = convert_text(post['text']) # converting text into normal form
        tmp_dict['text_length'] = len(post['text']) # calculating text length
        tmp_dict['post_hour'] = datetime.datetime.fromtimestamp(post['date']).strftime('%H') # parsing only post hour
        tmp_dict['post_month'] = datetime.datetime.fromtimestamp(post['date']).strftime('%m') # and post month
        tmp_dict['signed'] = int(post['from_id'] != -57354358) # checking whether post is signed or not
        # checking if any attacment exists
        tmp_dict['attachment_type'] = post['attachment']['type'] if 'is_pinned' in post.keys() else None
        tmp_dict['pinned'] = 1 if 'is_pinned' in post.keys() else 0 # cheking if post is pinned
        tmp_dict['repost'] = 1 if post['post_type'] == 'copy' else 0 # cheking if repost
        updated_posts.append(tmp_dict)
        progress.value += 1 # increasing progressbar value
    progress.description = 'Done convertion!'
    return updated_posts

# %% [markdown]
# Converting list of posts into new more convenient one.

# %%
converted_posts = convert_posts(loaded_posts)

# %%
converted_posts[4]
# Out:
# {'attachment_type': None,
#  'likes_number': 1,
#  'pinned': 0,
#  'post_hour': '13',
#  'post_month': 'April',
#  'repost': 0,
#  'signed': 0,
#  'text': ['почитать',
#   'комментарий',
#   'наш',
#   'студент',
#   'в',
#   'различный',
#   'группа',
#   'стыдно',
#   'становиться',
#   'за',
#   'то',
#   'что',
#   'вшэ',
#   'плодоносить',
#   'такой',
#   'даун',
#   'сколько',
#   'абитуриент',
#   'отогнать',
#   'свой',
#   'выебон',
#   'этот',
#   'долбануть',
#   'первокурсник',
#   'и',
#   'второкурсник',
#   'что-то',
#   'пытаться',
#   'доказывать',
#   'писать',
#   'что',
#   'наш',
#   'днищенский',
#   'вшм',
#   'хороший',
#   'чем',
#   'питерский',
#   'что',
#   'наш',
#   'вуз',
#   'есть',
#   'в',
#   'весь',
#   'рейтинг',
#   'на',
#   'лидировать',
#   'позиция',
#   'зачем',
#   'позорить-то',
#   'мы',
#   'будто',
#   'намеренно',
#   'это',
#   'писать',
#   'когда',
#   'знать',
#   'что',
#   'в',
#   'рейтинг',
#   'мы',
#   'далеко',
#   'кроме',
#   'экономика',
#   'вообще',
#   'бесить'],
#  'text_length': 467}

# %% [markdown]
# # 3. Creating object-feature matrix

# %% [markdown]
# Loading pandas

# %%
import pandas as pd

# %%
pd.DataFrame(converted_posts)
# Out:
#       attachment_type  likes_number  pinned post_hour post_month  repost  \
# 0               photo            71       1        13      April       0
# 1                None             7       0        20      April       1
# 2                None            20       0        16      April       0
# 3                None             1       0        13      April       0
# 4                None             1       0        13      April       0
# 5                None             5       0        22      April       0
# 6                None             2       0        21      April       0
# 7                None             2       0        13      April       0
# 8                None            21       0        13      April       0
# 9                None             9       0        19      April       0
# 10               None             3       0        16      April       0
# 11               None            51       0        10      April       0
# 12               None             1       0        21      April       0
# 13               None           129       0        15      April       0
# 14               None             0       0        12      April       0
# 15               None            61       0        11      April       0
# 16               None             9       0        08      April       0
# 17               None            14       0        23      April       0
# 18               None             5       0        17      April       0
# 19               None             8       0        17      April       0
# 20               None            35       0        15      April       0
# 21               None             4       0        14      April       0
# 22               None            34       0        11      April       0
# 23               None            15       0        08      April       0
# 24               None            53       0        22      April       0
# 25               None            37       0        20      April       0
# 26               None             4       0        17      April       0
# 27               None             3       0        14      April       0
# 28               None             0       0        12      April       0
# 29               None             4       0        12      April       0
# ...               ...           ...     ...       ...        ...     ...
# 13094            None            17       0        22     August       0
# 13095            None            11       0        21     August       0
# 13096            None            11       0        21     August       0
# 13097            None             6       0        21     August       0
# 13098            None             2       0        20     August       0
# 13099            None             7       0        19     August       0
# 13100            None             8       0        18     August       0
# 13101            None            23       0        18     August       0
# 13102            None             7       0        14     August       0
# 13103            None             7       0        11     August       0
# 13104            None            94       0        08     August       0
# 13105            None             1       0        01     August       0
# 13106            None             1       0        01     August       0
# 13107            None            17       0        01     August       0
# 13108            None             7       0        17     August       0
# 13109            None             6       0        17     August       0
# 13110            None            51       0        16     August       0
# 13111            None            10       0        14     August       0
# 13112            None            12       0        14     August       0
# 13113            None            20       0        09     August       0
# 13114            None            18       0        07     August       0
# 13115            None            22       0        07     August       0
# 13116            None             9       0        18     August       0
# 13117            None             7       0        17     August       0
# 13118            None            20       0        16     August       0
# 13119            None             4       0        15     August       0
# 13120            None            15       0        15     August       0
# 13121            None             1       0        14     August       0
# 13122            None            18       0        14     August       0
# 13123            None            31       0        14     August       0
#
#        signed                                               text  text_length
# 0           0                                                 []            0
# 1           0  [восхищать, удивительный, недееспособность, бо...          410
# 2           0  [иногда, я, жалеть, что, не, поступить, на, би...          163
# 3           0  [можно, ли, ходить, на, лекция, другой, факуль...           79
# 4           0  [почитать, комментарий, наш, студент, в, разли...          467
# 5           0  [сегодня, в, здание, вышка, на, курский, в, ак...          215
# 6           0  [хэй, вейпереть, а, знаешь, ли, ты, что, в, но...          780
# 7           0  [в, чем, разница, между, вышкинский, олимпиада...           87
# 8           0  [анонимно, добрый, вечер, господин, помнить, н...         1320
# 9           0  [ребята, мгту, мгу, вшэ, собраться, вместе, чт...          349
# 10          0  [паша, с, 1, курс, стат, почему, ты, обращать,...          191
# 11          0                   [как, же, я, хотеть, спать, ...]           22
# 12          0  [результат, олимпиада, пост, писать, направлен...          199
# 13          0                                                 []            0
# 14          0  [ребёнок-дипломник, кто, как, бороться, с, ант...          431
# 15          0                                                 []            0
# 16          0  [тем, время, прислать, результат, олимпиада, д...          133
# 17          0  [почему, фейс-контроль, в, клуб, не, являться,...          111
# 18          0  [абитура, магистратура, заканчивать, вышка, вс...          267
# 19          0  [ребята, есть, ли, среди, вы, тот, кто, на, ма...          159
# 20          0                                                 []            0
# 21          0  [вот, проводить, опрос, про, препод, и, что-то...           91
# 22          0  [в, три, общага, заблокировать, весь, порносай...           61
# 23          0  [а, вы, знать, что, некоторый, преподаватель, ...          235
# 24          0  [ходить, слух, что, рубль, скоро, стать, офици...           71
# 25          0                                                 []            0
# 26          0  [ребята, если, в, общага, стул, сломаться, то,...          149
# 27          0  [уважаемый, четверокурсник, юрфак, пожалуйста,...          371
# 28          0  [«, решение, суд, быть, постановить, ликвидиро...          188
# 29          0  [в, старое, добрый, время, писать, реферат, от...          535
# ...       ...                                                ...          ...
# 13094       0  [первокурсник, что, за, всеобщий, паника, ещё,...          178
# 13095       0  [я, первокурсница, жутко, бояться, что, не, на...          300
# 13096       0  [я, первокурсница, и, пока, что, ни, раз, не, ...          300
# 13097       0  [ребята, мы, уже, большой, 150, человек, сегод...          134
# 13098       0  [я, первокурсница, и, очень, бояться, не, впис...          143
# 13099       0  [завидовать, бела, зависть, тем, кома, повезти...          290
# 13100       0  [попасть, в, вышка, совершенно, от, фонарь, ре...          288
# 13101       0  [я, уже, надоесть, спорый, с, свой, бывший, од...          200
# 13102       0  [я, первокурсница, и, я, с, ужас, ждать, тести...          329
# 13103       0  [парень, который, писать, что, он, мучить, сов...          188
# 13104       0  [я, первокурсник, только, поступить, в, вышка,...           62
# 13105       0  [я, давно, мечтать, о, вышка, в, это, год, нак...          300
# 13106       0                                     [порвать, мир]           10
# 13107       0  [я, первокурсник, поступить, в, вшэ, по, олимп...          300
# 13108       0                           [слишком, дорого, драть]           24
# 13109       0  [я, за, лето, большой, всего, соскучиться, по,...          130
# 13110       0  [а, я, преподаватель, в, вшэ, я, ещё, никогда,...          140
# 13111       0  [а, я, бояться, что, сосед, в, общага, не, быт...           77
# 13112       0  [первое, сентябрь, тот, год, быть, поразить, ч...          334
# 13113       0  [ребята, запоминать, весь-весь, свой, одногруп...          264
# 13114       0  [в, ожидание, новое, необыкновенно, новое, нов...          183
# 13115       0  [когда, я, поступать, в, вышка, я, очень, боят...          325
# 13116       0  [я, тоже, познакомиться, с, прекрасный, девушк...          551
# 13117       0  [тоже, только, поступить, в, группа, факультет...          295
# 13118       0  [привет, недавно, у, мой, старенький, собака, ...          412
# 13119       0  [скоро, в, подслушать, hse, быть, много, подпи...          243
# 13120       0  [я, первокурсница, весь, школа, мечтать, о, ву...          220
# 13121       0  [занимательность, страничка, зависеть, только,...          116
# 13122       0  [хэй, первокурсник, удача, в, учёба, вы, не, о...          217
# 13123       0  [я, поступить, в, это, год, в, вышка, на, би, ...          270
#
# [13124 rows x 9 columns]
