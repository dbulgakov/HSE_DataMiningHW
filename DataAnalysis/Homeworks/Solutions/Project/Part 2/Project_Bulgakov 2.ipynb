# %% [markdown]
# # Data analysis project

# %% [markdown]
# _In this project I am going to write a program to predict the number likes post is going to get in vk._

# %% [markdown]
# __Выполнил__: Булгаков Дмитрий (ИАД16)
#
# __Дедлайн__: 23:59 10.04.16

# %% [markdown]
# # 1. Loading Data

# %% [markdown]
# VK library quiet installation and import into the notebook.

# %%
# !pip install vk # makes it quiet
import vk

# %% [markdown]
# Starting new vk session in order to parse data

# %%
vk_session = vk.Session() # starting new session
vk_api = vk.API(vk_session)

# %% [markdown]
# Getting number of posts in selected vk group.

# %%
selected_group = 'hse_overheard' # no other ideas :c
posts_number = vk_api.wall.get(domain=selected_group)[0] # number of posts is stored in first element
print('Number of posts in selected group: ', posts_number - 1)
# Out:
# Number of posts in selected group:  13977

# %% [markdown]
# Writing a function to parse more, than 100 posts from group.

# %%
def load_all_posts(page, n_posts, api):
    all_posts = api.wall.get(domain=page, count=n_posts)
    n_loaded = len(all_posts)
    while n_loaded < n_posts: # loop to load more, than 100 posts
        s = api.wall.get(domain=page, offset=n_loaded, count=(n_posts - n_loaded)) # update offset
        all_posts += s[1:] # no need for first element
        n_loaded += len(s) - 1 # update n_loaded
    return all_posts

# %% [markdown]
# Loading all posts from group for future analysis

# %%
try:
    loaded_posts = load_all_posts(page=selected_group, n_posts=2501, api=vk_api)[1:] # no need for posts number element
    # 1500 for this time, because I have small amount of ram avaliable :c
    print('Number of loaded posts: ', len(loaded_posts))
except: # timout errors are often to occur
    print('Error occured! Try again.')
# Out:
# Number of loaded posts:  2500

# %% [markdown]
# # 2. Data preprocessing

# %% [markdown]
# Loading required libs to preprocess data.

# %%
# !pip install pymorphy2 -q # silent install again
# !pip install stop_words -q # needed to remove stop words
from stop_words import get_stop_words
import pymorphy2 # need this one to convert words to normal time
import datetime # needed to convert response date 
import string # needed to work with strings
from nltk.tokenize import TweetTokenizer # needed to split text
import pandas as pd # required to work with dataframes
from ipywidgets import IntProgress # progressbar
from IPython.display import display # progressbar

# %% [markdown]
# Writing functions to process text data. Converting words to normal form and removing punctuation here.

# %%
def split_text(text):
    tokenizer = TweetTokenizer()
    return tokenizer.tokenize(text) # spliting text into words

def convert_to_normal_form(words_list):
    morph = pymorphy2.MorphAnalyzer()
    normal_forms_list = []
    for word in words_list:
        if word not in string.punctuation and word[0] != "<":
            norm_form = morph.parse(word)[0].normal_form #getting normal form of a word
            normal_forms_list.append(norm_form) #adding it to list
    return normal_forms_list

def convert_text(text):
    words_list = split_text(text) # spliting text into words
    norm_words_list = convert_to_normal_form(words_list) # words into normal form
    filtered_words = [w for w in norm_words_list if not w in get_stop_words('russian')] # removing stop words
    return " ".join(filtered_words) # joining words to a sentence again

# %% [markdown]
# Writing a function to convert received list into another with another data.

# %%
def check_attachment(post):
    if 'attachments' not in post.keys():
        return 0
    else:
        if len(post['attachments']) > 1:
            return 1
        else:
            if post['attachments'][0] == 'photo':
                return 2
            if post['attachments'][0] == 'link':
                return 3
            if post['attachments'][0] == 'poll':
                return 4
            return 5

# %%
def convert_posts(posts_list):
    progress = IntProgress() 
    progress.max = len(posts_list) # initializing progressbar
    progress.description = 'Processing data convertion'
    display(progress)
    current_date = pd.datetime.today()
    
    updated_posts = [] # list of new posts' list structure
    for i, post in enumerate(posts_list): 
        tmp_dict = {} # creating empty dictionary for each post
        tmp_dict['likes_number'] = int(post['likes']['count']) # getting likes count
        tmp_dict['text'] = convert_text(post['text']) # converting text into normal form
        tmp_dict['long_text'] = 1 if len(post['text']) > 400 else 0 # calculating text length
        post_date = datetime.datetime.fromtimestamp(post['date'])
        tmp_dict['post_hour'] = int(post_date.strftime('%H')) # parsing only post hour
        tmp_dict['post_month'] = int(post_date.strftime('%m')) # and post month
        tmp_dict['signed'] = int(post['from_id'] != -57354358) # checking whether post is signed or not
        # checking if any attacment exists
        tmp_dict['old_post'] = 1 if (current_date - post_date).days > 7 else 0
        tmp_dict['with_attachment'] = 1 if 'attachment' in post.keys() else 0
        tmp_dict['attachment_type'] = check_attachment(post)
        tmp_dict['pinned'] = 1 if 'is_pinned' in post.keys() else 0 # cheking if post is pinned
        tmp_dict['repost'] = 1 if post['post_type'] == 'copy' else 0 # cheking if repost
        updated_posts.append(tmp_dict)
        progress.value += 1 # increasing progressbar value
    progress.description = 'Done convertion!'
    return updated_posts

# %% [markdown]
# Converting list of posts into new more convenient one.

# %%
converted_posts = convert_posts(loaded_posts)

# %% [markdown]
# # 3. Creating object-feature matrix

# %% [markdown]
# Loading pandas

# %%
import pandas as pd

# %% [markdown]
# Creating dataframe from parsed data

# %%
posts_frame = pd.DataFrame(converted_posts)
posts_frame.head()
# Out:
#    attachment_type  likes_number  long_text  old_post  pinned  post_hour  \
# 0                5             0          0         0       0         12
# 1                0             0          0         0       0         11
# 2                1             0          1         0       0         15
# 3                0             1          0         0       0         10
# 4                5             9          1         0       0          9
#
#    post_month  repost  signed  \
# 0           6       0       0
# 1           6       0       0
# 2           6       0       0
# 3           6       0       0
# 4           6       0       0
#
#                                                 text  with_attachment
# 0  заслуживать мнение россия отстранение олимпиад...                1
# 1  китаец получить большинство право приход дэн с...                0
# 2  конкурс « подслушать » вместе билайн продолжат...                1
# 3                  чей лошадка победить мисс ниу вшэ                0
# 4  писать сюда придумать способ найти эконом гей ...                1

# %% [markdown]
# And describing posts data

# %%
posts_frame.describe()
# Out:
#        attachment_type  likes_number    long_text    old_post  pinned  \
# count      2500.000000   2500.000000  2500.000000  2500.00000  2500.0
# mean          1.240800     32.283600     0.141200     0.99360     0.0
# std           2.123916     48.877745     0.348297     0.07976     0.0
# min           0.000000      0.000000     0.000000     0.00000     0.0
# 25%           0.000000      4.000000     0.000000     1.00000     0.0
# 50%           0.000000     14.000000     0.000000     1.00000     0.0
# 75%           1.000000     42.000000     0.000000     1.00000     0.0
# max           5.000000    584.000000     1.000000     1.00000     0.0
#
#          post_hour   post_month       repost  signed  with_attachment
# count  2500.000000  2500.000000  2500.000000  2500.0      2500.000000
# mean     15.266000     5.778000     0.028400     0.0         0.279200
# std       5.941495     3.350523     0.166146     0.0         0.448696
# min       0.000000     1.000000     0.000000     0.0         0.000000
# 25%      12.000000     3.000000     0.000000     0.0         0.000000
# 50%      16.000000     5.000000     0.000000     0.0         0.000000
# 75%      20.000000     9.000000     0.000000     0.0         1.000000
# max      23.000000    12.000000     1.000000     0.0         1.000000

# %%
posts_frame
# Out:
#       attachment_type  likes_number  long_text  old_post  pinned  post_hour  \
# 0                   5             0          0         0       0         12
# 1                   0             0          0         0       0         11
# 2                   1             0          1         0       0         15
# 3                   0             1          0         0       0         10
# 4                   5             9          1         0       0          9
# 5                   0             4          0         0       0         18
# 6                   1             1          1         0       0         16
# 7                   0            50          0         0       0         19
# 8                   0             1          0         0       0         22
# 9                   5             0          0         0       0         19
# 10                  0             3          0         0       0         20
# 11                  0             0          0         0       0         15
# 12                  0             6          0         0       0         21
# 13                  0             6          0         0       0         18
# 14                  0             4          1         0       0         23
# 15                  0             6          0         0       0         14
# 16                  0            50          1         1       0          9
# 17                  0            10          1         1       0         22
# 18                  5           174          0         1       0         10
# 19                  0            14          0         1       0          0
# 20                  0            17          0         1       0         20
# 21                  5             0          0         1       0         18
# 22                  0             2          0         1       0         14
# 23                  5            43          0         1       0         10
# 24                  0            33          0         1       0          0
# 25                  0             0          0         1       0         20
# 26                  0             9          0         1       0         19
# 27                  0            63          0         1       0         13
# 28                  0             1          0         1       0         10
# 29                  0             7          0         1       0         21
# ...               ...           ...        ...       ...     ...        ...
# 2470                0            10          0         1       0         20
# 2471                1            25          0         1       0         16
# 2472                0             7          0         1       0         15
# 2473                0             0          0         1       0         15
# 2474                0             3          0         1       0         14
# 2475                0             3          0         1       0          8
# 2476                0            17          0         1       0         21
# 2477                0            19          0         1       0         20
# 2478                5            16          0         1       0         19
# 2479                0             0          0         1       0         17
# 2480                0             8          0         1       0         14
# 2481                0             3          0         1       0         22
# 2482                0            17          0         1       0         20
# 2483                0            17          1         1       0         16
# 2484                0            16          0         1       0         15
# 2485                0            27          0         1       0         14
# 2486                1            18          0         1       0          2
# 2487                0             8          0         1       0         20
# 2488                0             9          0         1       0         20
# 2489                5           203          0         1       0         14
# 2490                0            61          0         1       0         12
# 2491                0             9          0         1       0         12
# 2492                0            19          0         1       0         10
# 2493                5            18          0         1       0          1
# 2494                0             6          0         1       0         23
# 2495                0             6          0         1       0         22
# 2496                5             4          0         1       0         21
# 2497                5             3          0         1       0         20
# 2498                0            59          0         1       0         17
# 2499                0            14          0         1       0         12
#
#       post_month  repost  signed  \
# 0              6       0       0
# 1              6       0       0
# 2              6       0       0
# 3              6       0       0
# 4              6       0       0
# 5              6       0       0
# 6              6       0       0
# 7              6       0       0
# 8              6       0       0
# 9              6       0       0
# 10             6       0       0
# 11             6       0       0
# 12             6       0       0
# 13             6       0       0
# 14             6       0       0
# 15             6       0       0
# 16             6       0       0
# 17             6       0       0
# 18             6       0       0
# 19             6       0       0
# 20             6       0       0
# 21             6       0       0
# 22             6       0       0
# 23             6       0       0
# 24             6       0       0
# 25             6       0       0
# 26             6       0       0
# 27             6       1       0
# 28             6       0       0
# 29             6       0       0
# ...          ...     ...     ...
# 2470           6       0       0
# 2471           6       0       0
# 2472           6       0       0
# 2473           6       0       0
# 2474           6       0       0
# 2475           6       0       0
# 2476           6       0       0
# 2477           6       0       0
# 2478           6       0       0
# 2479           6       0       0
# 2480           6       0       0
# 2481           6       0       0
# 2482           6       0       0
# 2483           6       0       0
# 2484           6       0       0
# 2485           6       0       0
# 2486           6       0       0
# 2487           6       0       0
# 2488           6       0       0
# 2489           6       0       0
# 2490           6       0       0
# 2491           6       0       0
# 2492           6       0       0
# 2493           6       0       0
# 2494           6       0       0
# 2495           6       0       0
# 2496           6       0       0
# 2497           6       0       0
# 2498           6       0       0
# 2499           6       0       0
#
#                                                    text  with_attachment
# 0     заслуживать мнение россия отстранение олимпиад...                1
# 1     китаец получить большинство право приход дэн с...                0
# 2     конкурс « подслушать » вместе билайн продолжат...                1
# 3                     чей лошадка победить мисс ниу вшэ                0
# 4     писать сюда придумать способ найти эконом гей ...                1
# 5     политика тошнить вброса вуз конкретно надоесть...                0
# 6     конкурс « подслушать » вместе билайн продолжат...                1
# 7                 валерий ларченко самый сочный поп ___                0
# 8     студент кирпичный справляться программа репетитор                0
# 9           вопрос волновать миллион skyrim mass effect                1
# 10                          аль-багдади мёртвый прогноз                0
# 11       относиться поведение русский болельщик франция                0
# 12    самый любимый трек поделиться устать студент к...                0
# 13    выпуск заниматься студент прикладной математик...                0
# 14    поступать юрфак набигай регион общага родитель...                0
# 15    рассказать чувствовать узнать поступить хороши...                0
# 16    удивительно 30-40 оставаться чайлдфри убедить ...                0
# 17    научный интерес 30 существовать феминистка арб...                0
# 18                                         идти экзамен                1
# 19    считать нормальный отблагодарить препод войти ...                0
# 20    сайт выпускной вышка 2016 двигатель — преобраз...                0
# 21    вшэ относиться либерал каков удельный вес сред...                1
# 22    вышкинец нибыть берлин конец июнь :) ставить л...                0
# 23                                                                     1
# 24    кардинально измениться ибо отныне вбросовый вш...                0
# 25                        правда майнор сделать платный                0
# 26    сверхважный вопрос отличаться антиплагиат вышк...                0
# 27    общепит должный хороший высокий школа экономик...                0
# 28    ограничение служба офицер военка плюс сильно г...                0
# 29    совет дать абитуриент будущий первокурсник лай...                0
# ...                                                 ...              ...
# 2470        ставить лайк дональд трамп президент россия                0
# 2471                                                                   1
# 2472  кто-нибудь полететь новый российский полуостро...                0
# 2473               вышка преподаватель заниматься бегом                0
# 2474                  эконом ловить голубой омар жарить                0
# 2475  диплом бакалавр 240 зачётный единица карнеги 6...                0
# 2476  пройти выпуститься вшэ измениться появиться хо...                0
# 2477  вышка должный оправдать вложение надежда выпус...                0
# 2478  экономика украина нужный помощь карпаты отдохн...                1
# 2479                   проходить увлекательный каникулы                0
# 2480  20 серьёзный отношение мимолётно постоянно коб...                0
# 2481                       спросить упускать кто-нибудь                0
# 2482  зоофил друг педофил страдать общество признать...                0
# 2483  женитьба геев – определённый мнение повод сове...                0
# 2484  грек сваливать еврозона хохол лезть равно абит...                0
# 2485  толерантность медицинский термин означать утра...                0
# 2486                                          #lovewins                1
# 2487  #четамугрек выйти ес дефолт бу-де-т твёрдо чёт...                0
# 2488  китай развалить кпк раздавить майдан ввести це...                0
# 2489                                                                   1
# 2490  окончание сессия желать отличный лето кальянны...                0
# 2491  выгодно инженер впк производить новое образец ...                0
# 2492  кузьмин фон либеральный первак-вторак прочий ш...                0
# 2493  « понимать ругаться » ректор вшэ критиковать п...                1
# 2494  бесить первак рекламировать фак вроде мирэк во...                0
# 2495  встречать вышка заинтересовать наука сделать к...                0
# 2496                                    р разочарование                1
# 2497  господин милый дама нужный совет заняться ближ...                1
# 2498  рф предусмотреть пожизненный заключение женщин...                0
# 2499  призёр олимпиада первое уровень попадать бюдже...                0
#
# [2500 rows x 11 columns]

# %% [markdown]
# Creating object-feature matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # loading count vectorizer

cv = TfidfVectorizer(norm='l1', max_features = 200, analyzer = 'word', strip_accents='unicode', binary=True)
train_features = cv.fit_transform(posts_frame['text']).toarray() # vectorizing texts
train_frame = posts_frame.join(pd.DataFrame(train_features, columns=cv.get_feature_names())) # transfering it to pandas

train_frame.drop(['likes_number','text'],inplace=True,axis=1,errors='ignore') # removing unnecessary columns
value_frame = posts_frame['likes_number']

# %%
train_frame.describe()
# Out:
#        attachment_type    long_text    old_post  pinned    post_hour  \
# count      2500.000000  2500.000000  2500.00000  2500.0  2500.000000
# mean          1.240800     0.141200     0.99360     0.0    15.266000
# std           2.123916     0.348297     0.07976     0.0     5.941495
# min           0.000000     0.000000     0.00000     0.0     0.000000
# 25%           0.000000     0.000000     1.00000     0.0    12.000000
# 50%           0.000000     0.000000     1.00000     0.0    16.000000
# 75%           1.000000     0.000000     1.00000     0.0    20.000000
# max           5.000000     1.000000     1.00000     0.0    23.000000
#
#         post_month       repost  signed  with_attachment           10  \
# count  2500.000000  2500.000000  2500.0      2500.000000  2500.000000
# mean      5.778000     0.028400     0.0         0.279200     0.005379
# std       3.350523     0.166146     0.0         0.448696     0.054891
# min       1.000000     0.000000     0.0         0.000000     0.000000
# 25%       3.000000     0.000000     0.0         0.000000     0.000000
# 50%       5.000000     0.000000     0.0         0.000000     0.000000
# 75%       9.000000     0.000000     0.0         1.000000     0.000000
# max      12.000000     1.000000     0.0         1.000000     1.000000
#
#           ...            читать          что      чувство        школа  \
# count     ...       2500.000000  2500.000000  2500.000000  2500.000000
# mean      ...          0.003294     0.003716     0.003599     0.003476
# std       ...          0.036761     0.028349     0.043884     0.032310
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...          0.000000     0.000000     0.000000     0.000000
# 50%       ...          0.000000     0.000000     0.000000     0.000000
# 75%       ...          0.000000     0.000000     0.000000     0.000000
# max       ...          1.000000     0.565135     1.000000     1.000000
#
#            экзамен       эконом    экономика    экономист  экономическии  \
# count  2500.000000  2500.000000  2500.000000  2500.000000    2500.000000
# mean      0.006618     0.004686     0.005682     0.002732       0.001914
# std       0.060976     0.048383     0.041034     0.027555       0.022320
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.000000     0.000000     0.000000     0.000000       0.000000
# 50%       0.000000     0.000000     0.000000     0.000000       0.000000
# 75%       0.000000     0.000000     0.000000     0.000000       0.000000
# max       1.000000     1.000000     1.000000     0.530192       0.507208
#
#               язык
# count  2500.000000
# mean      0.002888
# std       0.032767
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 209 columns]

# %% [markdown]
# Saving train frame to file

# %%
# train_frame.to_csv('traindata.csv')

# %% [markdown]
# # 4. Comparing different methods

# %% [markdown]
# Splitting into train and test samples

# %%
from sklearn.cross_validation import train_test_split

# Splitting it into test and train samples
X_train, X_test, y_train, y_test = train_test_split(train_frame, value_frame, test_size=0.3, random_state=42)

# %% [markdown]
# Importing libs

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
def compare(est, param, est_name):
    cv = GridSearchCV(est, param, n_jobs = -1)
    cv.fit(X_train, y_train);
    print('CV best score for', est_name, ': ', cv.best_score_)
    
    predicted = cv.predict(X_test)
    mse = mean_squared_error(y_test, predicted)
    print('MSE for', est_name, ':' , mse)
    r2 = r2_score(y_test, predicted)
    print('R^2 for', est_name, ':' , r2)

# %% [markdown]
# ## 4.1 Linear regression

# %% [markdown]
# ### 4.1.1 Simple linear regression

# %%
parameters = {'fit_intercept':[True, False],'normalize':[True, False]}
compare(LinearRegression(), parameters, 'simple linear regression')
# Out:
# CV best score for simple linear regression :  0.00350830846095
# MSE for simple linear regression : 2588.30613169
# R^2 for simple linear regression : 0.0970898289022

# %% [markdown]
# ### 4.1.2 Linear regression with L1 regularization

# %%
parameters = {'alpha':np.arange(1, 100, 5), 'positive':[True, False],'normalize':[True, False], 
              'selection':['cyclic', 'random']}
compare(Lasso(), parameters, 'linear regression with L1 regularization')
# Out:
# CV best score for linear regression with L1 regularization :  0.14050366586
# MSE for linear regression with L1 regularization : 2434.19940939
# R^2 for linear regression with L1 regularization : 0.150848743005

# %% [markdown]
# ### 4.1.3 Linear regression with L2 regularization

# %%
parameters = {'alpha':np.logspace(1.0, 10.0, 101.00), 'fit_intercept':[True, False],'normalize':[True, False],
              'solver':['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'auto']}
compare(Ridge(), parameters, 'linear regression with L2 regularization')

# %% [markdown]
# ## 4.2 Decision trees and random forests

# %% [markdown]
# ### 4.2.1 DecisionTreeClassifier

# %%
parameters = {'presort':[True, False],'max_depth': np.arange(1, 20), 'class_weight':['balanced', None], 'splitter':['random', 'best'],
             'max_features':['auto', 'sqrt', 'log2', None]}
compare(tree.DecisionTreeClassifier(), parameters, 'decision tree classifier')

# %% [markdown]
# ### 4.2.2 RandomForestClassifier

# %%
parameters = {'n_estimators':[10, 20, 30],
             'max_features':['auto', 'sqrt', 'log2', None]}
compare(RandomForestClassifier(), parameters, 'random forest classifier')

# %% [markdown]
# ### 4.3 kNN

# %%
parameters = {'leaf_size':np.arange(30, 100, 10),'n_neighbors': np.arange(5, 20), 
              'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute']}
compare(KNeighborsClassifier(), parameters, 'kNN')
